# %% [markdown]
# # <font style="color:RGB(173, 3, 252)">CSC 126 - GRAPHICS AND VISUAL COMPUTING </font>
#
# AUTHOR: James Earl D. Cubillas, M.Sc

# %% [markdown]
# <h1>Neural Transfer</h1>

# %% [markdown]
# **Importing Packages**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
import matplotlib.pyplot as plt

import torchvision.transforms as transforms
from torchvision.models import vgg19, VGG19_Weights


import copy

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_device(device)

# %% [markdown]
# **Loading the Images**

# %%
imsize = 512 if torch.cuda.is_available() else 128

loader = transforms.Compose([
    transforms.Resize(imsize),
    transforms.ToTensor()
])

def image_loader(image_name):
    image = Image.open(image_name)
    image = loader(image).unsqueeze(0)
    return image.to(device, torch.float)

style_img = image_loader("data/universe4.jpg")
content_img = image_loader("data/dancing.jpg")

assert style_img.size() == content_img.size()

# %%
unloader = transforms.ToPILImage()

plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()
    image = image.squeeze(0)
    image = unloader(image)
    plt.imshow(image)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

plt.figure()
imshow(style_img, title='Style Image')

plt.figure()
imshow(content_img, title='Content Image')

# %% [markdown]
# **Loss Functions**

# %% [markdown]
# ***Content Loss***

# %%
class ContentLoss(nn.Module):

    def __init__(self,target,):
        super(ContentLoss, self).__init__()
        self.target = target.detach()

    def forward(self, input):
        self.loss = F.mse_loss(input, self.target)
        return input

# %% [markdown]
# ***Style Loss***

# %%
def gram_matrix(input):
    a,b,c,d = input.size()

    features = input.view(a * b, c*d)

    G = torch.mm(features, features.t())

    return G.div(a * b * c * d)

class StyleLoss(nn.Module):
    
    def __init__(self, target_feature):
        super(StyleLoss,self).__init__()
        self.target = gram_matrix(target_feature).detach()

    def forward(self, input):
        G = gram_matrix(input)
        self.loss = F.mse_loss(G, self.target)
        return input

# %% [markdown]
# **Importing the Model**

# %%
cnn = vgg19(weights=VGG19_Weights.DEFAULT).features.eval()

# %%
cnn_normalization_mean = torch.tensor([0.485, 0.456, 0.406])
cnn_normalization_std = torch.tensor([0.299, 0.224, 0.225])

class Normalization(nn.Module):
    def __init__(self,mean,std):
        super(Normalization,self).__init__()
        self.mean = torch.tensor(mean).view(-1,1,1)
        self.std = torch.tensor(std).view(-1,1,1)

    def forward(self,img):
        return(img - self.mean)/ self.std

# %%
#Sequential

# desired depth layers to compute style/content losses :
content_layers_default = ['conv_4']
style_layers_default = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

def get_style_model_and_losses(cnn, normalization_mean, normalization_std,
                               style_img, content_img,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default):
    # normalization module
    normalization = Normalization(normalization_mean, normalization_std)

    # just in order to have an iterable access to or list of content/style
    # losses
    content_losses = []
    style_losses = []

    # assuming that ``cnn`` is a ``nn.Sequential``, so we make a new ``nn.Sequential``
    # to put in modules that are supposed to be activated sequentially
    model = nn.Sequential(normalization)

    i = 0  # increment every time we see a conv
    for layer in cnn.children():
        if isinstance(layer, nn.Conv2d):
            i += 1
            name = 'conv_{}'.format(i)
        elif isinstance(layer, nn.ReLU):
            name = 'relu_{}'.format(i)
            # The in-place version doesn't play very nicely with the ``ContentLoss``
            # and ``StyleLoss`` we insert below. So we replace with out-of-place
            # ones here.
            layer = nn.ReLU(inplace=False)
        elif isinstance(layer, nn.MaxPool2d):
            name = 'pool_{}'.format(i)
        elif isinstance(layer, nn.BatchNorm2d):
            name = 'bn_{}'.format(i)
        else:
            raise RuntimeError('Unrecognized layer: {}'.format(layer.__class__.__name__))

        model.add_module(name, layer)

        if name in content_layers:
            # add content loss:
            target = model(content_img).detach()
            content_loss = ContentLoss(target)
            model.add_module("content_loss_{}".format(i), content_loss)
            content_losses.append(content_loss)

        if name in style_layers:
            # add style loss:
            target_feature = model(style_img).detach()
            style_loss = StyleLoss(target_feature)
            model.add_module("style_loss_{}".format(i), style_loss)
            style_losses.append(style_loss)

    # now we trim off the layers after the last content and style losses
    for i in range(len(model) - 1, -1, -1):
        if isinstance(model[i], ContentLoss) or isinstance(model[i], StyleLoss):
            break

    model = model[:(i + 1)]

    return model, style_losses, content_losses

# %% [markdown]
# **Content Image or White noise**

# %%
input_img = content_img.clone()
# if you want to use white noise by using the following code:
#
# .. code-block:: python
#
#    input_img = torch.randn(content_img.data.size())

# add the original input image to the figure:
plt.figure()
imshow(input_img, title='Input Image')

# %% [markdown]
# **Gradient Descent**

# %%
def get_input_optimizer(input_img):
    optimizer = optim.LBFGS([input_img])
    return optimizer

# %% [markdown]
# **Style Transfer Function**

# %%
def run_style_transfer(cnn, normalization_mean, normalization_std,
                       content_img, style_img, input_img, num_steps=10000,
                       style_weight=1000000, content_weight=1):
    """Run the style transfer."""
    print('Building the style transfer model..')
    model, style_losses, content_losses = get_style_model_and_losses(cnn,
        normalization_mean, normalization_std, style_img, content_img)

    # We want to optimize the input and not the model parameters so we
    # update all the requires_grad fields accordingly
    input_img.requires_grad_(True)
    # We also put the model in evaluation mode, so that specific layers
    # such as dropout or batch normalization layers behave correctly.
    model.eval()
    model.requires_grad_(False)

    optimizer = get_input_optimizer(input_img)

    print('Optimizing..')
    run = [0]
    while run[0] <= num_steps:

        def closure():
            # correct the values of updated input image
            with torch.no_grad():
                input_img.clamp_(0, 1)

            optimizer.zero_grad()
            model(input_img)
            style_score = 0
            content_score = 0

            for sl in style_losses:
                style_score += sl.loss
            for cl in content_losses:
                content_score += cl.loss

            style_score *= style_weight
            content_score *= content_weight

            loss = style_score + content_score
            loss.backward()

            run[0] += 1
            if run[0] % 50 == 0:
                print("run {}:".format(run))
                print('Style Loss : {:4f} Content Loss: {:4f}'.format(
                    style_score.item(), content_score.item()))
                print()

            return style_score + content_score

        optimizer.step(closure)

    # a last correction...
    with torch.no_grad():
        input_img.clamp_(0, 1)

    return input_img

# %% [markdown]
# ***Run the Algorithm***

# %%
output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img,style_img,input_img)

plt.figure()
imshow(output, title='Output Image')

plt.ioff()
plt.show()
# Out:
# Building the style transfer model..
# Optimizing..
# run [50]:
# Style Loss : 80.845398 Content Loss: 12.976381
#
# run [100]:
# Style Loss : 19.425692 Content Loss: 13.906770
#
# run [150]:
# Style Loss : 8.596042 Content Loss: 12.859911
#
# run [200]:
# Style Loss : 5.473896 Content Loss: 11.963243
#
# run [250]:
# Style Loss : 4.087526 Content Loss: 11.286419
#
# run [300]:
# Style Loss : 3.391714 Content Loss: 10.782504
#
# run [350]:
# Style Loss : 2.943406 Content Loss: 10.446991
#
# run [400]:
# Style Loss : 2.704051 Content Loss: 10.193017
#
# run [450]:
# Style Loss : 2.579536 Content Loss: 10.009119
#
# run [500]:
# Style Loss : 2.483002 Content Loss: 9.870668
#
# run [550]:
# Style Loss : 2.386744 Content Loss: 9.789117
#
# run [600]:
# Style Loss : 2.386464 Content Loss: 9.709559
#
# run [650]:
# Style Loss : 2.368287 Content Loss: 9.690965
#
# run [700]:
# Style Loss : 2.832292 Content Loss: 9.768577
#
# run [750]:
# Style Loss : 2.465993 Content Loss: 9.758005
#
# run [800]:
# Style Loss : 2.577637 Content Loss: 9.818982
#
# run [850]:
# Style Loss : 2.534292 Content Loss: 9.866264
#
# run [900]:
# Style Loss : 2.490757 Content Loss: 9.894824
#
# run [950]:
# Style Loss : 2.544973 Content Loss: 9.947909
#
# run [1000]:
# Style Loss : 2.859205 Content Loss: 10.225659
#
# run [1050]:
# Style Loss : 2.997325 Content Loss: 10.426782
#
# run [1100]:
# Style Loss : 3.843640 Content Loss: 10.426910
#
# run [1150]:
# Style Loss : 3.791800 Content Loss: 10.355472
#
# run [1200]:
# Style Loss : 3.751874 Content Loss: 10.549294
#
# run [1250]:
# Style Loss : 3.778431 Content Loss: 10.346554
#
# run [1300]:
# Style Loss : 16.487572 Content Loss: 10.816251
#
# run [1350]:
# Style Loss : 3.172572 Content Loss: 10.556637
#
# run [1400]:
# Style Loss : 2677.931152 Content Loss: 20.438406
#
# run [1450]:
# Style Loss : 3748204.750000 Content Loss: 201.352661
#
# run [1500]:
# Style Loss : 551.522278 Content Loss: 28.738873
#
# run [1550]:
# Style Loss : 282.069214 Content Loss: 28.220829
#
# run [1600]:
# Style Loss : 117.777046 Content Loss: 26.665726
#
# run [1650]:
# Style Loss : 31.824526 Content Loss: 24.764992
#
# run [1700]:
# Style Loss : 12.420849 Content Loss: 22.027693
#
# run [1750]:
# Style Loss : 8.101649 Content Loss: 19.601545
#
# run [1800]:
# Style Loss : 6.019033 Content Loss: 17.890863
#
# run [1850]:
# Style Loss : 4.991199 Content Loss: 16.589075
#
# run [1900]:
# Style Loss : 4.477971 Content Loss: 15.541779
#
# run [1950]:
# Style Loss : 4.143922 Content Loss: 14.752098
#
# run [2000]:
# Style Loss : 3.916686 Content Loss: 14.078918
#
# run [2050]:
# Style Loss : 3.661804 Content Loss: 13.504130
#
# run [2100]:
# Style Loss : 3.543506 Content Loss: 13.036351
#
# run [2150]:
# Style Loss : 3.388645 Content Loss: 12.713203
#
# run [2200]:
# Style Loss : 3.409771 Content Loss: 12.435862
#
# run [2250]:
# Style Loss : 3.238229 Content Loss: 12.165959
#
# run [2300]:
# Style Loss : 5.301710 Content Loss: 12.000387
#
# run [2350]:
# Style Loss : 3.361929 Content Loss: 11.881528
#
# run [2400]:
# Style Loss : 5.588058 Content Loss: 11.626992
#
# run [2450]:
# Style Loss : 22806260.000000 Content Loss: 442.470612
#
# run [2500]:
# Style Loss : 872.872437 Content Loss: 27.519556
#
# run [2550]:
# Style Loss : 390.968109 Content Loss: 26.931850
#
# run [2600]:
# Style Loss : 186.420654 Content Loss: 26.197319
#
# run [2650]:
# Style Loss : 60.343845 Content Loss: 25.212231
#
# run [2700]:
# Style Loss : 17.790733 Content Loss: 22.982555
#
# run [2750]:
# Style Loss : 8.124861 Content Loss: 19.677229
#
# run [2800]:
# Style Loss : 5.660160 Content Loss: 17.060753
#
# run [2850]:
# Style Loss : 4.506421 Content Loss: 15.513147
#
# run [2900]:
# Style Loss : 4.012704 Content Loss: 14.404387
#
# run [2950]:
# Style Loss : 3.560332 Content Loss: 13.643946
#
# run [3000]:
# Style Loss : 3.371428 Content Loss: 13.047379
#
# run [3050]:
# Style Loss : 3.513817 Content Loss: 12.496520
#
# run [3100]:
# Style Loss : 3.288765 Content Loss: 12.115648
#
# run [3150]:
# Style Loss : 2.982298 Content Loss: 11.871667
#
# run [3200]:
# Style Loss : 3.387806 Content Loss: 11.679185
#
# run [3250]:
# Style Loss : 3.051786 Content Loss: 11.531509
#
# run [3300]:
# Style Loss : 4.075560 Content Loss: 11.459499
#
# run [3350]:
# Style Loss : 3.338613 Content Loss: 11.454216
#
# run [3400]:
# Style Loss : 5.190327 Content Loss: 11.343214
#
# run [3450]:
# Style Loss : 3.467213 Content Loss: 11.375000
#
# run [3500]:
# Style Loss : 3.124207 Content Loss: 11.219299
#
# run [3550]:
# Style Loss : 3.587263 Content Loss: 11.163560
#
# run [3600]:
# Style Loss : 8.948128 Content Loss: 11.025525
#
# run [3650]:
# Style Loss : 2.936739 Content Loss: 11.078321
#
# run [3700]:
# Style Loss : 2.587055 Content Loss: 10.897627
#
# run [3750]:
# Style Loss : 8.288680 Content Loss: 10.782172
#
# run [3800]:
# Style Loss : 2.994250 Content Loss: 10.783289
#
# run [3850]:
# Style Loss : 2.928331 Content Loss: 10.668947
#
# run [3900]:
# Style Loss : 2.758846 Content Loss: 10.567183
#
# run [3950]:
# Style Loss : 33.884434 Content Loss: 15.457532
#
# run [4000]:
# Style Loss : 5.739455 Content Loss: 13.514989
#
# run [4050]:
# Style Loss : 2.981475 Content Loss: 11.919349
#
# run [4100]:
# Style Loss : 2.389021 Content Loss: 11.006593
#
# run [4150]:
# Style Loss : 2.126814 Content Loss: 10.496972
#
# run [4200]:
# Style Loss : 1.997932 Content Loss: 10.147778
#
# run [4250]:
# Style Loss : 1.934688 Content Loss: 9.959174
#
# run [4300]:
# Style Loss : 1.933096 Content Loss: 9.834246
#
# run [4350]:
# Style Loss : 1.928789 Content Loss: 9.779665
#
# run [4400]:
# Style Loss : 2.064054 Content Loss: 9.759476
#
# run [4450]:
# Style Loss : 1.944402 Content Loss: 9.709999
#
# run [4500]:
# Style Loss : 2.086258 Content Loss: 9.769454
#
# run [4550]:
# Style Loss : 2.201781 Content Loss: 9.822501
#
# run [4600]:
# Style Loss : 2.339623 Content Loss: 9.871249
#
# run [4650]:
# Style Loss : 2.552860 Content Loss: 10.087829
#
# run [4700]:
# Style Loss : 2.625870 Content Loss: 9.965085
#
# run [4750]:
# Style Loss : 3.174335 Content Loss: 10.457713
#
# run [4800]:
# Style Loss : 4.147240 Content Loss: 10.354020
#
# run [4850]:
# Style Loss : 36.676529 Content Loss: 13.204721
#
# run [4900]:
# Style Loss : 3.490880 Content Loss: 11.171451
#
# run [4950]:
# Style Loss : 2.899766 Content Loss: 10.320515
#
# run [5000]:
# Style Loss : 2.976701 Content Loss: 10.161721
#
# run [5050]:
# Style Loss : 2.827305 Content Loss: 10.265615
#
# run [5100]:
# Style Loss : 10.622614 Content Loss: 10.384731
#
# run [5150]:
# Style Loss : 8.490442 Content Loss: 10.132870
#
# run [5200]:
# Style Loss : 10.069661 Content Loss: 10.656162
#
# run [5250]:
# Style Loss : 3.505794 Content Loss: 10.942625
#
# run [5300]:
# Style Loss : 2.882521 Content Loss: 10.334970
#
# run [5350]:
# Style Loss : 16276234.000000 Content Loss: 399.883881
#
# run [5400]:
# Style Loss : 10011.575195 Content Loss: 30.877951
#
# run [5450]:
# Style Loss : 506.921844 Content Loss: 27.329721
#
# run [5500]:
# Style Loss : 243.323685 Content Loss: 26.345108
#
# run [5550]:
# Style Loss : 74.491066 Content Loss: 24.296143
#
# run [5600]:
# Style Loss : 21.165668 Content Loss: 22.612698
#
# run [5650]:
# Style Loss : 9.813422 Content Loss: 19.453871
#
# run [5700]:
# Style Loss : 6.043005 Content Loss: 16.955030
#
# run [5750]:
# Style Loss : 4.381919 Content Loss: 15.224752
#
# run [5800]:
# Style Loss : 3.578004 Content Loss: 14.026983
#
# run [5850]:
# Style Loss : 3.132616 Content Loss: 13.081012
#
# run [5900]:
# Style Loss : 2.861883 Content Loss: 12.438640
#
# run [5950]:
# Style Loss : 2.665138 Content Loss: 11.925629
#
# run [6000]:
# Style Loss : 2.548871 Content Loss: 11.505995
#
# run [6050]:
# Style Loss : 2.455957 Content Loss: 11.197351
#
# run [6100]:
# Style Loss : 2.384923 Content Loss: 10.921558
#
# run [6150]:
# Style Loss : 2.348018 Content Loss: 10.689356
#
# run [6200]:
# Style Loss : 2.610403 Content Loss: 10.521601
#
# run [6250]:
# Style Loss : 2.466274 Content Loss: 10.333778
#
# run [6300]:
# Style Loss : 3.104855 Content Loss: 10.214583
#
# run [6350]:
# Style Loss : 2.253566 Content Loss: 10.109550
#
# run [6400]:
# Style Loss : 2.311700 Content Loss: 9.996571
#
# run [6450]:
# Style Loss : 2.270757 Content Loss: 9.938070
#
# run [6500]:
# Style Loss : 2.698117 Content Loss: 9.915563
#
# run [6550]:
# Style Loss : 2.258142 Content Loss: 9.796105
#
# run [6600]:
# Style Loss : 2.488678 Content Loss: 9.813641
#
# run [6650]:
# Style Loss : 2.164896 Content Loss: 9.730618
#
# run [6700]:
# Style Loss : 2.178927 Content Loss: 9.785258
#
# run [6750]:
# Style Loss : 2.382523 Content Loss: 9.748374
#
# run [6800]:
# Style Loss : 579.948914 Content Loss: 10.792506
#
# run [6850]:
# Style Loss : 12986790.000000 Content Loss: 337.830566
#
# run [6900]:
# Style Loss : 576.925598 Content Loss: 27.326904
#
# run [6950]:
# Style Loss : 293.888031 Content Loss: 26.191057
#
# run [7000]:
# Style Loss : 107.340652 Content Loss: 24.997965
#
# run [7050]:
# Style Loss : 30.109835 Content Loss: 23.595175
#
# run [7100]:
# Style Loss : 11.091951 Content Loss: 20.891439
#
# run [7150]:
# Style Loss : 6.365373 Content Loss: 18.277973
#
# run [7200]:
# Style Loss : 4.651863 Content Loss: 16.567991
#
# run [7250]:
# Style Loss : 3.757038 Content Loss: 15.178701
#
# run [7300]:
# Style Loss : 3.297277 Content Loss: 14.232126
#
# run [7350]:
# Style Loss : 3.023283 Content Loss: 13.518324
#
# run [7400]:
# Style Loss : 2.899251 Content Loss: 12.921652
#
# run [7450]:
# Style Loss : 2.840609 Content Loss: 12.386102
#
# run [7500]:
# Style Loss : 2.730444 Content Loss: 11.982669
#
# run [7550]:
# Style Loss : 2.666937 Content Loss: 11.659766
#
# run [7600]:
# Style Loss : 2.629297 Content Loss: 11.361243
#
# run [7650]:
# Style Loss : 2.580312 Content Loss: 11.144518
#
# run [7700]:
# Style Loss : 2.688523 Content Loss: 10.904592
#
# run [7750]:
# Style Loss : 2.387809 Content Loss: 10.696714
#
# run [7800]:
# Style Loss : 2.352731 Content Loss: 10.504805
#
# run [7850]:
# Style Loss : 2.275307 Content Loss: 10.355643
#
# run [7900]:
# Style Loss : 2.203576 Content Loss: 10.197807
#
# run [7950]:
# Style Loss : 2.213688 Content Loss: 10.075123
#
# run [8000]:
# Style Loss : 2.242652 Content Loss: 9.987535
#
# run [8050]:
# Style Loss : 4.734533 Content Loss: 10.019822
#
# run [8100]:
# Style Loss : 2.218171 Content Loss: 9.763988
#
# run [8150]:
# Style Loss : 2.129779 Content Loss: 9.749902
#
# run [8200]:
# Style Loss : 2.136488 Content Loss: 9.707563
#
# run [8250]:
# Style Loss : 2.208638 Content Loss: 9.631540
#
# run [8300]:
# Style Loss : 2.193984 Content Loss: 9.679556
#
# run [8350]:
# Style Loss : 2.334100 Content Loss: 9.721915
#
# run [8400]:
# Style Loss : 2.187572 Content Loss: 9.639043
#
# run [8450]:
# Style Loss : 2.222607 Content Loss: 9.604916
#
# run [8500]:
# Style Loss : 3.653451 Content Loss: 9.820906
#
# run [8550]:
# Style Loss : 2.419320 Content Loss: 9.745056
#
# run [8600]:
# Style Loss : 2.782341 Content Loss: 9.688425
#
# run [8650]:
# Style Loss : 2.783506 Content Loss: 10.006893
#
# run [8700]:
# Style Loss : 2.654046 Content Loss: 10.020732
#
# run [8750]:
# Style Loss : 2.405877 Content Loss: 9.836884
#
# run [8800]:
# Style Loss : 3.395108 Content Loss: 9.933159
#
# run [8850]:
# Style Loss : 3.786177 Content Loss: 10.731732
#
# run [8900]:
# Style Loss : 2.417737 Content Loss: 9.821451
#
# run [8950]:
# Style Loss : 2.182471 Content Loss: 9.590889
#
# run [9000]:
# Style Loss : 2.475261 Content Loss: 9.589304
#
# run [9050]:
# Style Loss : 16.782696 Content Loss: 9.443508
#
# run [9100]:
# Style Loss : 2.426952 Content Loss: 9.800831
#
# run [9150]:
# Style Loss : 2.116325 Content Loss: 9.405452
#
# run [9200]:
# Style Loss : 2.059705 Content Loss: 9.380891
#
# run [9250]:
# Style Loss : 22878866.000000 Content Loss: 466.396912
#
# run [9300]:
# Style Loss : 1181.426880 Content Loss: 27.919151
#
# run [9350]:
# Style Loss : 462.429352 Content Loss: 26.822094
#
# run [9400]:
# Style Loss : 183.269562 Content Loss: 25.290195
#
# run [9450]:
# Style Loss : 64.800598 Content Loss: 23.787643
#
# run [9500]:
# Style Loss : 28.116093 Content Loss: 21.695084
#
# run [9550]:
# Style Loss : 12.179584 Content Loss: 18.669117
#
# run [9600]:
# Style Loss : 6.866659 Content Loss: 16.370836
#
# run [9650]:
# Style Loss : 4.618464 Content Loss: 14.538349
#
# run [9700]:
# Style Loss : 3.585778 Content Loss: 13.413378
#
# run [9750]:
# Style Loss : 3.253612 Content Loss: 12.509747
#
# run [9800]:
# Style Loss : 2.762470 Content Loss: 11.975572
#
# run [9850]:
# Style Loss : 2.750513 Content Loss: 11.432658
#
# run [9900]:
# Style Loss : 2.475941 Content Loss: 11.111725
#
# run [9950]:
# Style Loss : 2.407212 Content Loss: 10.803127
#
# run [10000]:
# Style Loss : 2.412924 Content Loss: 10.579742

# %% [markdown]
# ***Save the Transformed Image with the Art Style***

# %%
out_t = (output.data.squeeze())
output_img = transforms.ToPILImage()(out_t)
output_img.save('output.png')
output_img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
